# %% [markdown]
# # Import packages

# %%
import pandas as pd

# %% [markdown]
# # Load data

# %%
DATASET_FOLDER = '../../datasets/tempetes'
path = DATASET_FOLDER + '/' + 'monthly_hist_temperatures.csv'

# %%
hist_temp = pd.read_csv(path,sep = ",")
hist_temp = hist_temp.drop(["Unnamed: 0", "Statistics"], axis = 1)
hist_temp = hist_temp.rename({"Temperature - (Celsius)":"avg_monthly_temperature"}, axis=1)

# %%
hist_temp.head()
# Out:
#        Country ISO3  Month  avg_monthly_temperature  Year
# 0  Afghanistan  AFG      1                 -0.03780  1901
# 1  Afghanistan  AFG      2                  2.42348  1901
# 2  Afghanistan  AFG      3                  9.36230  1901
# 3  Afghanistan  AFG      4                 13.55640  1901
# 4  Afghanistan  AFG      5                 18.15090  1901

# %% [markdown]
# # Prepare data s.t. to join it with emdat db

# %%
hist_temp_by_year_by_country_agg = hist_temp.groupby(["ISO3", "Year"]).agg({"avg_monthly_temperature": ["mean", "min", "max", "median"]}).reset_index()

# %%
column_headers = []
for i in range(len(list(hist_temp_by_year_by_country_agg.columns.get_level_values(0)))):
    str0 = list(hist_temp_by_year_by_country_agg.columns.get_level_values(0))[i]
    str1 = list(hist_temp_by_year_by_country_agg.columns.get_level_values(1))[i]
    header = str0 + "_" + str1
    column_headers.append(header)

# %%
column_headers
# Out:
# ['ISO3_',
#  'Year_',
#  'avg_monthly_temperature_mean',
#  'avg_monthly_temperature_min',
#  'avg_monthly_temperature_max',
#  'avg_monthly_temperature_median']

# %%
hist_temp_by_year_by_country_agg.columns = column_headers

# %%
hist_temp_by_year_by_country_agg.head()
# Out:
#   ISO3_  Year_  avg_monthly_temperature_mean  avg_monthly_temperature_min  \
# 0   AFG   1901                     13.172872                     -0.03780
# 1   AFG   1902                     13.342649                      2.32874
# 2   AFG   1903                     12.006417                     -1.58800
# 3   AFG   1904                     12.531729                     -5.55450
# 4   AFG   1905                     12.267143                     -1.84350
#
#    avg_monthly_temperature_max  avg_monthly_temperature_median
# 0                      25.3787                        12.42005
# 1                      25.0482                        12.68190
# 2                      24.7819                        12.54385
# 3                      25.0061                        11.41170
# 4                      25.1425                        13.78495

# %%
hist_temp_by_year_by_country_agg.shape
# Out:
# (21112, 6)

# %% [markdown]
# # Join on emdat db

# %% [markdown]
# ### Import emdat db

# %%
DATASET_FOLDER = '../../datasets/tempetes'
path = DATASET_FOLDER + '/' + 'wb_disasters_bdd.xlsx'

# %%
disasters_df = pd.read_excel(path)
disasters_df.head()
# Out:
#           Dis No  Year   Seq Disaster Group Disaster Subgroup Disaster Type  \
# 0  1900-9002-CPV  1900  9002        Natural    Climatological       Drought
# 1  1900-9001-IND  1900  9001        Natural    Climatological       Drought
# 2  1904-0003-BGD  1904     3        Natural    Meteorological         Storm
# 3  1906-0023-BEL  1906    23        Natural      Hydrological         Flood
# 4  1906-0024-BEL  1906    24        Natural      Hydrological         Flood
#
#    Disaster Subtype Disaster Subsubtype Event Name Entry Criteria  ...  \
# 0           Drought                 NaN        NaN            NaN  ...
# 1           Drought                 NaN        NaN            NaN  ...
# 2  Tropical cyclone                 NaN        NaN           OFDA  ...
# 3               NaN                 NaN        NaN         Govern  ...
# 4               NaN                 NaN        NaN         Govern  ...
#
#   End Day Total Deaths No Injured No Affected No Homeless Total Affected  \
# 0     NaN      11000.0        NaN         NaN         NaN            NaN
# 1     NaN    1250000.0        NaN         NaN         NaN            NaN
# 2     NaN          NaN        NaN         NaN         NaN            NaN
# 3    14.0          6.0        NaN         NaN         NaN            NaN
# 4     NaN          NaN        NaN         NaN         NaN            NaN
#
#   Reconstruction Costs ('000 US$) Insured Damages ('000 US$)  \
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                             NaN                        NaN
# 4                             NaN                        NaN
#
#   Total Damages ('000 US$)       CPI
# 0                      NaN  3.261389
# 1                      NaN  3.261389
# 2                      NaN  3.522300
# 3                      NaN  3.522300
# 4                      NaN  3.522300
#
# [5 rows x 43 columns]

# %% [markdown]
# ### Filter on storms

# %%
storms_df = disasters_df[disasters_df["Disaster Type"]=="Storm"]

# %%
storms_df.shape
# Out:
# (4328, 43)

# %% [markdown]
# # Join

# %%
hist_temp_by_year_by_country_agg.dtypes
# Out:
# ISO3_                              object
# Year_                               int64
# avg_monthly_temperature_mean      float64
# avg_monthly_temperature_min       float64
# avg_monthly_temperature_max       float64
# avg_monthly_temperature_median    float64
# dtype: object

# %%
storms_df["Start Year"] = storms_df["Start Year"].astype("int64")
# Out:
# C:\Users\clotilde.pety\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
storms_by_year_by_country_hist_temp = pd.merge(storms_df, hist_temp_by_year_by_country_agg, how="left", left_on=["Start Year", "ISO"], right_on=["Year_", "ISO3_"])

# %%
storms_by_year_by_country_hist_temp.head()
# Out:
#           Dis No  Year  Seq Disaster Group Disaster Subgroup Disaster Type  \
# 0  1904-0003-BGD  1904    3        Natural    Meteorological         Storm
# 1  1906-0015-HKG  1906   15        Natural    Meteorological         Storm
# 2  1909-0010-BGD  1909   10        Natural    Meteorological         Storm
# 3  1909-0013-BGD  1909   13        Natural    Meteorological         Storm
# 4  1909-0012-HTI  1909   12        Natural    Meteorological         Storm
#
#    Disaster Subtype Disaster Subsubtype Event Name Entry Criteria  ...  \
# 0  Tropical cyclone                 NaN        NaN           OFDA  ...
# 1  Tropical cyclone                 NaN        NaN           Kill  ...
# 2  Tropical cyclone                 NaN        NaN           Kill  ...
# 3  Tropical cyclone                 NaN        NaN           OFDA  ...
# 4  Tropical cyclone                 NaN        NaN           Kill  ...
#
#   Reconstruction Costs ('000 US$) Insured Damages ('000 US$)  \
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                             NaN                        NaN
# 4                             NaN                        NaN
#
#   Total Damages ('000 US$)     CPI ISO3_   Year_ avg_monthly_temperature_mean  \
# 0                      NaN  3.5223   BGD  1904.0                    24.628058
# 1                  20000.0  3.5223   HKG  1906.0                    22.230708
# 2                      NaN  3.5223   BGD  1909.0                    25.008875
# 3                      NaN  3.5223   BGD  1909.0                    25.008875
# 4                      NaN  3.5223   HTI  1909.0                    23.569458
#
#   avg_monthly_temperature_min avg_monthly_temperature_max  \
# 0                     17.7866                     27.9551
# 1                     14.5506                     28.6989
# 2                     18.6933                     28.3398
# 3                     18.6933                     28.3398
# 4                     21.4873                     25.1208
#
#   avg_monthly_temperature_median
# 0                       26.70140
# 1                       22.73545
# 2                       26.69000
# 3                       26.69000
# 4                       23.70925
#
# [5 rows x 49 columns]

# %%
storms_by_year_by_country_hist_temp_sel_cols = storms_by_year_by_country_hist_temp[["Start Year", 
                                                                                    "ISO", 
                                                                                    "Disaster Type",
                                                                                    "No Affected",
                                                                                    "Total Damages ('000 US$)",
                                                                                    "avg_monthly_temperature_mean",
                                                                                    "avg_monthly_temperature_min",
                                                                                    "avg_monthly_temperature_max",
                                                                                    "avg_monthly_temperature_median"
                                                                                   ]]

# %%
storms_by_year_by_country_hist_temp_sel_cols.shape
# Out:
# (4328, 9)

# %%
storms_by_year_by_country_hist_temp_sel_cols.head()
# Out:
#    Start Year  ISO Disaster Type  No Affected  Total Damages ('000 US$)  \
# 0        1904  BGD         Storm          NaN                       NaN
# 1        1906  HKG         Storm          NaN                   20000.0
# 2        1909  BGD         Storm          NaN                       NaN
# 3        1909  BGD         Storm          NaN                       NaN
# 4        1909  HTI         Storm          NaN                       NaN
#
#    avg_monthly_temperature_mean  avg_monthly_temperature_min  \
# 0                     24.628058                      17.7866
# 1                     22.230708                      14.5506
# 2                     25.008875                      18.6933
# 3                     25.008875                      18.6933
# 4                     23.569458                      21.4873
#
#    avg_monthly_temperature_max  avg_monthly_temperature_median
# 0                      27.9551                        26.70140
# 1                      28.6989                        22.73545
# 2                      28.3398                        26.69000
# 3                      28.3398                        26.69000
# 4                      25.1208                        23.70925

# %% [markdown]
# # Write csv file in datasets > tempetes directory

# %%
storms_by_year_by_country_hist_temp_sel_cols.to_csv('../../datasets/tempetes/' + '/' + 'emdat_with_hist_temperatures.csv')
