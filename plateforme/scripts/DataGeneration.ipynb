# %%
a = [1900, 1910, 1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000, 2010,2020,2030,2040,2050,2060,2070,2080,2090,2100]
b = UN_Geosheme_Subregion=['Australia and New Zealand','Caribbean','Central America','Central Asia','Eastern Africa','Eastern Asia','Eastern Europe','Melanesia','Micronesia','Middle Africa','Northern Africa','Northern America','Northern Europe','Polynesia','South America','South-Eastern Asia','Southern Africa','Southern Asia','Southern Europe','Western Africa','Western Asia','Western Europe',]
c = ['Droughts', 'Floods', 'Storms']
d = [1,2,3,4]

# %%
import pandas as pd
from itertools import product
df = pd.DataFrame(list(product(a,b,c,d)), columns=['Decade','UN_Geosheme_Subregion','Disaster_Type','Climate_Scenario'])
df.loc[df.Decade < 2030, 'Climate_Scenario'] = None
df.drop_duplicates()
# Out:
#       Decade      UN_Geosheme_Subregion Disaster_Type  Climate_Scenario
# 0       1900  Australia and New Zealand      Droughts               NaN
# 4       1900  Australia and New Zealand        Floods               NaN
# 8       1900  Australia and New Zealand        Storms               NaN
# 12      1900                  Caribbean      Droughts               NaN
# 16      1900                  Caribbean        Floods               NaN
# ...      ...                        ...           ...               ...
# 5539    2100             Western Europe        Floods               4.0
# 5540    2100             Western Europe        Storms               1.0
# 5541    2100             Western Europe        Storms               2.0
# 5542    2100             Western Europe        Storms               3.0
# 5543    2100             Western Europe        Storms               4.0
#
# [2970 rows x 4 columns]

# %%
import numpy as np
df['Financial_mpact'] = np.random.randint(0,100000000, df.shape[0])
df['Human_Impact'] = np.random.randint(0,1000000, df.shape[0])
df['Disaster_Occurence'] = np.random.randint(0,100, df.shape[0])

# %%
df.to_csv('randominput.csv',index=False)
df
# Out:
#       Decade      UN_Geosheme_Subregion Disaster_Type  Climate_Scenario  \
# 0       1900  Australia and New Zealand      Droughts               NaN
# 1       1900  Australia and New Zealand      Droughts               NaN
# 2       1900  Australia and New Zealand      Droughts               NaN
# 3       1900  Australia and New Zealand      Droughts               NaN
# 4       1900  Australia and New Zealand        Floods               NaN
# ...      ...                        ...           ...               ...
# 5539    2100             Western Europe        Floods               4.0
# 5540    2100             Western Europe        Storms               1.0
# 5541    2100             Western Europe        Storms               2.0
# 5542    2100             Western Europe        Storms               3.0
# 5543    2100             Western Europe        Storms               4.0
#
#       Financial_mpact  Human_Impact  Disaster_Occurence
# ...
